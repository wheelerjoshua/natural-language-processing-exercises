# %% [markdown]
# ## Exercises
# The end result of this exercise should be a file named `prepare.py` that defines the requested functions.
#
# In this exercise we will be defining some functions to prepare textual data. These functions should apply equally well to both the codeup blog articles and the news articles that were previously acquired.
#
# 1. Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
#
# - Lowercase everything
# - Normalize unicode characters
# - Replace anything that is not a letter, number, whitespace or a single quote.
#
# 2. Define a function named `tokenize`. It should take in a string and tokenize all the words in the string.
#
# 3. Define a function named `stem`. It should accept some text and return the text after applying stemming to all the words.
#
# 4. Define a function named `lemmatize`. It should accept some text and return the text after applying lemmatization to each word.
#
# 5. Define a function named `remove_stopwords`. It should accept some text and return the text after removing all the stopwords.
#
#     This function should define two optional parameters, extra_words and exclude_words. These parameters should define any additional stop words to include, and any words that we don't want to remove.
#
#
# 6. Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe `news_df`.
#
# 7. Make another dataframe for the Codeup blog posts. Name the dataframe `codeup_df`.
#
# 8. For each dataframe, produce the following columns:
# - `title` to hold the title
# - `original` to hold the original article/post content
# - `clean` to hold the normalized and tokenized original with the stopwords removed.
# - `stemmed` to hold the stemmed version of the cleaned data.
# - `lemmatized` to hold the lemmatized version of the cleaned data.
#
# Ask yourself:
#
# If your corpus is 493KB, would you prefer to use stemmed or lemmatized text?
# If your corpus is 25MB, would you prefer to use stemmed or lemmatized text?
# If your corpus is 200TB of text and you're charged by the megabyte for your hosted computational resources, would you prefer to use stemmed or lemmatized text?

# %%
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import pandas as pd

from time import strftime

# %% [markdown]
# ### 1.

# %%
def basic_clean(s):
    # lowercase
    s = s.lower()
    # normalize
    s = unicodedata.normalize('NFKD', s)\
    .encode('ascii', 'ignore')\
    .decode('utf-8', 'ignore')
    # remove special characters
    s = re.sub(r"[^a-z0-9'\s]", '', s)
    return s

# %% [markdown]
# ### 2.

# %%
def tokenize(s):
    tokenizer = nltk.tokenize.ToktokTokenizer()
    return tokenizer.tokenize(s, return_str=True)

# %% [markdown]
# ### 3.

# %%
def stem(s):
    ps = nltk.porter.PorterStemmer()
    stems = [ps.stem(word) for word in s.split()]
    stemmed_s = ' '.join(stems)
    return stemmed_s

# %% [markdown]
# ### 4.

# %%
def lemmatize(s):
    wnl = nltk.stem.WordNetLemmatizer()
    lemmas = [wnl.lemmatize(word) for word in s.split()]
    lemmatized_s = ' '.join(lemmas)

    return lemmatized_s

# %% [markdown]
# ### 5.

# %%
def remove_stopwords(s, extra_words = [], exclude_words = []):
    '''
    Takes a string and removes stopwords.
    Optional arguments: 
    extra_words adds words to stopword list
    exclude_words words to keep
    '''
    stopword_list = stopwords.words('english')
    if len(extra_words) > 0:
        stopword_list.append(word for word in extra_words)
    if len(exclude_words) > 0:
        stopword_list.remove(word for word in exclude_words)
    
    words = s.split()
    filtered_words = [w for w in words if w not in stopword_list]
    s_without_stopwords = ' '.join(filtered_words)
    return s_without_stopwords

# %% [markdown]
# ### 6.

# %%
import acquire

# %%
news_df = acquire.acquire_news()
news_df.head()
# Out:
#                                                title          author  \
# 0  RBI cancels licence of Maha-based Independence...    Shalini Ojha
# 1          Boost to EVs a big step: Windmill Capital    Roshan Gupta
# 2  Facebook parent Meta's $230-billion wipeout bi...  Pragya Swastik
# 3  Facebook's daily active users fall for first t...  Pragya Swastik
# 4  Tesla co-worker used N-word, threw a hot tool ...    Kiran Khatri
#
#                                              content  category
# 0  RBI has cancelled licence of Maharashtra-based...  business
# 1  Increased use of EVs in public transport, spec...  business
# 2  Facebook's parent Meta's shares plunged 27% an...  business
# 3  Facebook has seen its daily active users (DAUs...  business
# 4  A former Tesla worker has filed a lawsuit agai...  business

# %% [markdown]
# ### 7.

# %%
codeup_df = acquire.acquire_blogs()
codeup_df.head()
# Out:
#                                                title  \
# 0                  Codeup Dallas Open House - Codeup
# 1  Codeup Helps 40 Grads Land Tech Jobs in Just 1...
# 2  IT Certifications 101: Why They Matter, and Wh...
# 3  A rise in cyber attacks means opportunities fo...
# 4  Use your GI Bill® benefits to Land a Job in Te...
#
#                                              content
# 0  \nCome join us for the re-opening of our Dalla...
# 1  \n\n\n\n\n\nOur Placement Team is simply defin...
# 2  \n\n\n\n\n\nAWS, Google, Azure, Red Hat, CompT...
# 3  \nIn the last few months, the US has experienc...
# 4  \n\n\n\n\n\nAs the end of military service get...

# %% [markdown]
# ### 8. For each dataframe, produce the following columns:
# - `title` to hold the title
# - `original` to hold the original article/post content
# - `clean` to hold the normalized and tokenized original with the stopwords removed.
# - `stemmed` to hold the stemmed version of the cleaned data.
# - `lemmatized` to hold the lemmatized version of the cleaned data.

# %%
# original
news_df['original']=news_df.content

# %%
# cleaned
clean_articles = []
for article in news_df.content:
    clean_articles.append(remove_stopwords(tokenize(basic_clean(article))))

news_df['clean'] = clean_articles

# %%
# stemmed
stemmed_articles = []
for article in news_df.clean:
    stemmed_articles.append(stem(article))

news_df['stemmed'] = stemmed_articles

# %%
# lemmatized
lemmatized_articles = []
for article in news_df.clean:
    lemmatized_articles.append(lemmatize(article))

news_df['lemmatized'] = stemmed_articles

# %% [markdown]
# Codeup

# %%
# original
codeup_df['original']=codeup_df.content

# %%
# cleaned
clean_articles = []
for article in codeup_df.content:
    clean_articles.append(remove_stopwords(tokenize(basic_clean(article))))

codeup_df['clean'] = clean_articles

# %%
# stemmed
stemmed_articles = []
for article in codeup_df.clean:
    stemmed_articles.append(stem(article))

codeup_df['stemmed'] = stemmed_articles

# %%
# lemmatized
lemmatized_articles = []
for article in codeup_df.clean:
    lemmatized_articles.append(lemmatize(article))

codeup_df['lemmatized'] = stemmed_articles

# %%
codeup_df
# Out:
#                                                 title  \
# 0                   Codeup Dallas Open House - Codeup
# 1   Codeup Helps 40 Grads Land Tech Jobs in Just 1...
# 2   IT Certifications 101: Why They Matter, and Wh...
# 3   A rise in cyber attacks means opportunities fo...
# 4   Use your GI Bill® benefits to Land a Job in Te...
# 5   Which program is right for me: Cyber Security ...
# 6       What the Heck is System Engineering? - Codeup
# 7   From Speech Pathology to Business Intelligence...
# 8              Boris - Behind the Billboards - Codeup
# 9   Is Codeup the Best Bootcamp in San Antonio...o...
# 10  Codeup Launches First Podcast: Hire Tech - Codeup
# 11  Why Should I Become a System Administrator? - ...
# 12  Announcing our Candidacy for Accreditation! - ...
# 13  Codeup Takes Over More of the Historic Vogue B...
# 14  Inclusion at Codeup During Pride Month (and Al...
#
#                                               content  \
# 0   \nCome join us for the re-opening of our Dalla...
# 1   \n\n\n\n\n\nOur Placement Team is simply defin...
# 2   \n\n\n\n\n\nAWS, Google, Azure, Red Hat, CompT...
# 3   \nIn the last few months, the US has experienc...
# 4   \n\n\n\n\n\nAs the end of military service get...
# 5   \n\n\n\n\n\nWhat IT Career should I choose?\nI...
# 6   \n\n\n\n\n\nCodeup offers a 13-week training p...
# 7   \n\n\n\n\n\nBy: Alicia Gonzalez\nBefore Codeup...
# 8                                              \n\n\n
# 9   \n\n\n\n\n\nLooking for the best data science ...
# 10  \nAny podcast enthusiasts out there? We are pl...
# 11  \n\n\n\n\n\nWith so many tech careers in deman...
# 12  \nDid you know that even though we’re an indep...
# 13  \nCodeup is moving into another floor of our H...
# 14  \nHappy Pride Month! Pride Month is a dedicate...
#
#                                              original  \
# 0   \nCome join us for the re-opening of our Dalla...
# 1   \n\n\n\n\n\nOur Placement Team is simply defin...
# 2   \n\n\n\n\n\nAWS, Google, Azure, Red Hat, CompT...
# 3   \nIn the last few months, the US has experienc...
# 4   \n\n\n\n\n\nAs the end of military service get...
# 5   \n\n\n\n\n\nWhat IT Career should I choose?\nI...
# 6   \n\n\n\n\n\nCodeup offers a 13-week training p...
# 7   \n\n\n\n\n\nBy: Alicia Gonzalez\nBefore Codeup...
# 8                                              \n\n\n
# 9   \n\n\n\n\n\nLooking for the best data science ...
# 10  \nAny podcast enthusiasts out there? We are pl...
# 11  \n\n\n\n\n\nWith so many tech careers in deman...
# 12  \nDid you know that even though we’re an indep...
# 13  \nCodeup is moving into another floor of our H...
# 14  \nHappy Pride Month! Pride Month is a dedicate...
#
#                                                 clean  \
# 0   come join us reopening dallas campus drinks sn...
# 1   placement team simply defined group manages re...
# 2   aws google azure red hat comptiathese big name...
# 3   last months us experienced dozens major cybera...
# 4   end military service gets closer many transiti...
# 5   career choose youre thinking career lot direct...
# 6   codeup offers 13week training program systems ...
# 7   alicia gonzalez codeup home health speechlangu...
# 8
# 9   looking best data science bootcamp world best ...
# 10  podcast enthusiasts pleased announce release c...
# 11  many tech careers demand choose system adminis...
# 12  know even though independent school multiple r...
# 13  codeup moving another floor historic vogue bui...
# 14  happy pride month pride month dedicated time c...
#
#                                               stemmed  \
# 0   come join us reopen dalla campu drink snack co...
# 1   placement team simpli defin group manag relati...
# 2   aw googl azur red hat comptiathes big name pro...
# 3   last month us experienc dozen major cyberattac...
# 4   end militari servic get closer mani transit se...
# 5   career choos your think career lot direct coul...
# 6   codeup offer 13week train program system engin...
# 7   alicia gonzalez codeup home health speechlangu...
# 8
# 9   look best data scienc bootcamp world best code...
# 10  podcast enthusiast pleas announc releas codeup...
# 11  mani tech career demand choos system administr...
# 12  know even though independ school multipl regul...
# 13  codeup move anoth floor histor vogu build down...
# 14  happi pride month pride month dedic time celeb...
#
#                                            lemmatized
# 0   come join us reopen dalla campu drink snack co...
# 1   placement team simpli defin group manag relati...
# 2   aw googl azur red hat comptiathes big name pro...
# 3   last month us experienc dozen major cyberattac...
# 4   end militari servic get closer mani transit se...
# 5   career choos your think career lot direct coul...
# 6   codeup offer 13week train program system engin...
# 7   alicia gonzalez codeup home health speechlangu...
# 8
# 9   look best data scienc bootcamp world best code...
# 10  podcast enthusiast pleas announc releas codeup...
# 11  mani tech career demand choos system administr...
# 12  know even though independ school multipl regul...
# 13  codeup move anoth floor histor vogu build down...
# 14  happi pride month pride month dedic time celeb...
